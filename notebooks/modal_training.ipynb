# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import DistanceMetric
from math import radians
from math import sin, cos, sqrt, atan2, radians

# %%
df = pd.read_csv('./data/restaurant.csv')
df.head(3)
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
#
#    Delivery_location_longitude Order_Date Time_Orderd Time_Order_picked  \
# 0                    78.116106   12-02-22       21:55             22:10
# 1                    76.347589   13-02-22       14:55             15:05
# 2                    74.006619   04-03-22       17:30             17:40
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# ...

# %%
def drop_un_col(df):

    df = df.drop(labels=["ID","Delivery_person_ID","Delivery_person_Age","Delivery_person_Ratings","Order_Date",],axis=1)
    return df

# %%
df = drop_un_col(df)

# %%
df.head()
# Out:
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude Time_Orderd Time_Order_picked  \
# 0                    78.116106       21:55             22:10
# 1                    76.347589       14:55             15:05
# 2                    74.006619       17:30             17:40
# 3                    75.829346        9:20              9:30
# 4                    80.502929       19:50             20:05
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                  Jam                  2         Snack
# ...

# %%
df.columns
# Out:
# Index(['Restaurant_latitude', 'Restaurant_longitude',
#        'Delivery_location_latitude', 'Delivery_location_longitude',
#        'Time_Orderd', 'Time_Order_picked', 'Weather_conditions',
#        'Road_traffic_density', 'Vehicle_condition', 'Type_of_order',
#        'Type_of_vehicle', 'multiple_deliveries', 'Festival', 'City',
#        'Time_taken (min)'],
#       dtype='object')

# %%
def cal_distance(lat1, lon1, lat2, lon2):
    R=6373.0
    dist = DistanceMetric.get_metric('haversine')
    
    X = [[radians(lat1), radians(lon1)], [radians(lat2), radians(lon2)]]
    distance_sklearn = R * dist.pairwise(X)
    return np.array(distance_sklearn).item(1)

# %%
df.head()
# Out:
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude Time_Orderd Time_Order_picked  \
# 0                    78.116106       21:55             22:10
# 1                    76.347589       14:55             15:05
# 2                    74.006619       17:30             17:40
# 3                    75.829346        9:20              9:30
# 4                    80.502929       19:50             20:05
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                  Jam                  2         Snack
# ...

# %%
df[df["Restaurant_longitude"]>0]
# Out:
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0                30.327968             78.046106                   30.397968
# 1                10.003064             76.307589                   10.043064
# 2                18.562450             73.916619                   18.652450
# 3                30.899584             75.809346                   30.919584
# 4                26.463504             80.372929                   26.593504
# ...                    ...                   ...                         ...
# 45578            23.371292             85.327872                   23.481292
# 45579            26.902328             75.794257                   26.912328
# 45581            13.022394             80.242439                   13.052394
# 45582            11.001753             76.986241                   11.041753
# 45583            23.351058             85.325731                   23.431058
#
# ...

# %%
#dropping negative values latitude
def drop_nagetive_value(df,column1,column2,column3,column4):
        

        df = df.loc[~((df[column1] < 0) | 
                    (df[column2] < 0) | 
                    (df[column3] < 0) | 
                    (df[column4] < 0))]
        
        return df

# %%
df = drop_nagetive_value(df,column1="Restaurant_latitude",column2="Restaurant_longitude",column3="Delivery_location_latitude",column4="Delivery_location_longitude")

# %%
df[df["Restaurant_latitude"]<0]
# Out:
# Empty DataFrame
# Columns: [Restaurant_latitude, Restaurant_longitude, Delivery_location_latitude, Delivery_location_longitude, Time_Orderd, Time_Order_picked, Weather_conditions, Road_traffic_density, Vehicle_condition, Type_of_order, Type_of_vehicle, multiple_deliveries, Festival, City, Time_taken (min)]
# Index: []

# %%
# def cal_the_distance(lat1, lon1, lat2, lon2):
#         R = 6373.0
#         dlon = radians(lon2) - radians(lon1)
#         dlat = radians(lat2) - radians(lat1)
            
#         a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
#         c = 2 * atan2(sqrt(a), sqrt(1 - a))
            
#         distance_haversine_formula = R * c
#         return distance_haversine_formula

# %%
# counting distance..
df['distance'] = df.apply(lambda x: cal_distance(x['Restaurant_latitude'], x['Restaurant_longitude'],  x['Delivery_location_latitude'],  x['Delivery_location_longitude']), axis=1)
# Out:
# C:\Users\KK\AppData\Local\Temp\ipykernel_2184\274660031.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['distance'] = df.apply(lambda x: cal_distance(x['Restaurant_latitude'], x['Restaurant_longitude'],  x['Delivery_location_latitude'],  x['Delivery_location_longitude']), axis=1)

# %%
df.columns
# Out:
# Index(['Restaurant_latitude', 'Restaurant_longitude',
#        'Delivery_location_latitude', 'Delivery_location_longitude',
#        'Time_Orderd', 'Time_Order_picked', 'Weather_conditions',
#        'Road_traffic_density', 'Vehicle_condition', 'Type_of_order',
#        'Type_of_vehicle', 'multiple_deliveries', 'Festival', 'City',
#        'Time_taken (min)', 'distance'],
#       dtype='object')

# %%
# now we dont need 4 columns Restaurant_latitude Restaurant_longitude Delivery_location_latitude Delivery_location_longitude
df.drop(columns=['Restaurant_latitude'], inplace=True)
df.drop(columns=['Restaurant_longitude'], inplace=True)
df.drop(columns=['Delivery_location_latitude'], inplace=True)
df.drop(columns=['Delivery_location_longitude'], inplace=True)
df.drop(columns=['Time_Orderd'], inplace=True)
df.drop(columns=['Time_Order_picked'], inplace=True)
# Out:
# C:\Users\KK\AppData\Local\Temp\ipykernel_2184\2101070148.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Restaurant_latitude'], inplace=True)
# C:\Users\KK\AppData\Local\Temp\ipykernel_2184\2101070148.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Restaurant_longitude'], inplace=True)
# C:\Users\KK\AppData\Local\Temp\ipykernel_2184\2101070148.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df.head()
### ----- features selection-------
# Out:
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                  Jam                  2         Snack
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle  multiple_deliveries Festival           City  \
# 0      motorcycle                  3.0       No  Metropolitian
# 1      motorcycle                  1.0       No  Metropolitian
# 2         scooter                  1.0       No  Metropolitian
# 3      motorcycle                  0.0       No  Metropolitian
# 4         scooter                  1.0       No  Metropolitian
#
#    Time_taken (min)   distance
# 0                46  10.283809
# 1                23   6.244278
# 2                21  13.792189
# ...

# %%
## Independent(Features) and dependent features(Labals)
X = df.drop(labels=['Time_taken (min)'],axis=1) 
y = df[['Time_taken (min)']]

# %%
# Define which columns should be ordinal-encoded and which should be Directly scaled
categorical_columns = X.select_dtypes(include="O").columns
numerical_columns = X.select_dtypes(include=("int","float64")).columns

# %%
df = df.reindex(columns=['Weather_conditions','Road_traffic_density','Vehicle_condition','Type_of_order',"Type_of_vehicle",'multiple_deliveries',"Festival",'City','distance','Time_taken (min)'])

# %%
df.to_csv('./data/restaurant_cleaned.csv')

# %%
df
# Out:
#       Weather_conditions Road_traffic_density  Vehicle_condition  \
# 0                    Fog                  Jam                  2
# 1                 Stormy                 High                  1
# 2             Sandstorms               Medium                  1
# 3             Sandstorms                  Low                  0
# 4                    Fog                  Jam                  1
# ...                  ...                  ...                ...
# 45579              Windy                 High                  1
# 45580              Windy                  Jam                  0
# 45581             Cloudy                  Low                  1
# 45582             Cloudy                 High                  0
# 45583                Fog               Medium                  2
#
#       Type_of_order Type_of_vehicle  multiple_deliveries Festival  \
# 0             Snack      motorcycle                  3.0       No
# ...

# %%
categorical_columns
# Out:
# Index(['Weather_conditions', 'Road_traffic_density', 'Type_of_order',
#        'Type_of_vehicle', 'Festival', 'City'],
#       dtype='object')

# %%
numerical_columns
# Out:
# Index(['Vehicle_condition', 'multiple_deliveries', 'distance'], dtype='object')

# %%
df.isnull().sum()
# Out:
# Weather_conditions       467
# Road_traffic_density     454
# Vehicle_condition          0
# Type_of_order              0
# Type_of_vehicle            0
# multiple_deliveries      985
# Festival                 228
# City                    1183
# distance                   0
# Time_taken (min)           0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer ## HAndling Missing Values Replace missing values using a descriptive statistic (Stretgy = mean, median, or most frequent) 
from sklearn.preprocessing import StandardScaler # Handling Feature scaling 
# Standardized data is essential for accurate data analysis; it’s easier to draw clear conclusions about your current data when you have other data to measure it against
# Scaling the features in a machine learning model can improve the optimization process by making the flow of gradient descent smoother and helping algorithms reach the minimum of the cost function more quickly.
from sklearn.preprocessing import OrdinalEncoder # ordinal encoder
## pipelines Basicly means it will going to connect my previous things that we did

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer # for Grouping this together

# %%
df[numerical_columns].head()
# Out:
#    Vehicle_condition  multiple_deliveries   distance
# 0                  2                  3.0  10.283809
# 1                  1                  1.0   6.244278
# 2                  1                  1.0  13.792189
# 3                  0                  0.0   2.931178
# 4                  1                  1.0  19.402707

# %%
df[categorical_columns].head()
# Out:
#   Weather_conditions Road_traffic_density Type_of_order Type_of_vehicle  \
# 0                Fog                  Jam         Snack      motorcycle
# 1             Stormy                 High          Meal      motorcycle
# 2         Sandstorms               Medium        Drinks         scooter
# 3         Sandstorms                  Low        Buffet      motorcycle
# 4                Fog                  Jam         Snack         scooter
#
#   Festival           City
# 0       No  Metropolitian
# 1       No  Metropolitian
# 2       No  Metropolitian
# 3       No  Metropolitian
# 4       No  Metropolitian

# %%
Weather_conditions_categories = ['Fog', 'Stormy', 'Sandstorms', 'Windy', 'Cloudy', 'Sunny']
Road_traffic_density_categories = ['Jam', 'High', 'Medium', 'Low']
Festival_categories = ['No', 'Yes']
City_categories = ['Metropolitian', 'Urban', 'Semi-Urban']
Type_of_vehicle_categories = ['motorcycle', 'scooter', 'electric_scooter', 'bicycle']

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
# # Numerical Pipeline
# common_pipeline = Pipeline(
#     steps=[("dropUnCol",drop_un_col(df)),
#            ("drop_nagetive_distance",drop_nagetive_value(df,column1="Restaurant_latitude",column2="Restaurant_longitude",column3="Delivery_location_latitude",column4="Delivery_location_longitude"))
# ]
# )

numerical_pipeline = Pipeline(
    steps=[("Imputing" ,SimpleImputer(strategy="median")),
           ("Standard",StandardScaler())
           ])

# Categorical Pipeline
categorcal_pipeline = Pipeline(
    steps=[
        ("imputer" , SimpleImputer(strategy="most_frequent")),
        ("Encoding" , OrdinalEncoder(categories=[Weather_conditions_categories,Road_traffic_density_categories,Festival_categories,City_categories,Type_of_vehicle_categories])),
        ("scaler" , StandardScaler())]
        )

# Now i need to combine these
preprocessor= ColumnTransformer(
[("numerical_pipeline",numerical_pipeline,numerical_columns),
("categorcal_pipeline",categorcal_pipeline,categorical_columns)
])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.30,random_state=16)

# %%
type(X_train)
# Out:
# pandas.core.frame.DataFrame

# %%
y_train
# Out:
#        Time_taken (min)
# 22597                24
# 32296                27
# 28746                36
# 17060                29
# 41712                21
# ...                 ...
# 37676                25
# 33721                33
# 33667                27
# 2188                 19
# 39974                21
#
# [31607 rows x 1 columns]

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('numerical_pipeline',
#                                  Pipeline(steps=[('Imputing',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('Standard',
#                                                   StandardScaler())]),
#                                  Index(['Vehicle_condition', 'multiple_deliveries', 'distance'], dtype='object')),
#                                 ('categorcal_pipeline',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('Encoding',
#                                                   OrdinalEncoder(categories=[['Fog',
#                                                                               'Stormy',
# ...

# %%
preprocessor.fit(X_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6856\2258745478.py in <module>
# ----> 1 preprocessor.fit(X_train)
#
# d:\Users\KK\anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py in fit(self, X, y)
#     640         # we use fit_transform to make sure to set sparse_output_ (for which we
#     641         # need the transformed data) to have consistent output type in predict
# --> 642         self.fit_transform(X, y=y)
#     643         return self
#     644
#
# d:\Users\KK\anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py in fit_transform(self, X, y)
#     673         self._validate_remainder(X)
#     674
# --> 675         result = self._fit_transform(X, y, _fit_transform_one)
#     676
#     677         if not result:
#
# ...

# %%
X_train = pd.DataFrame(preprocessor.fit_transform(X_train),columns=preprocessor.get_feature_names_out())
X_test= pd.DataFrame(preprocessor.transform(X_test),columns=preprocessor.get_feature_names_out())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6856\1747600759.py in <module>
# ----> 1 X_train = pd.DataFrame(preprocessor.fit_transform(X_train),columns=preprocessor.get_feature_names_out())
#       2 X_test= pd.DataFrame(preprocessor.transform(X_test),columns=preprocessor.get_feature_names_out())
#
# d:\Users\KK\anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py in fit_transform(self, X, y)
#     673         self._validate_remainder(X)
#     674
# --> 675         result = self._fit_transform(X, y, _fit_transform_one)
#     676
#     677         if not result:
#
# d:\Users\KK\anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py in _fit_transform(self, X, y, func, fitted, column_as_strings)
#     604         )
#     605         try:
# --> 606             return Parallel(n_jobs=self.n_jobs)(
# ...
